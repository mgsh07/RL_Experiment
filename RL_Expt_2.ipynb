# %% [markdown]
# <a href="https://colab.research.google.com/github/LeelaNandhaKishore1511/RL-Lab-Sem-5/blob/main/RL_Expt_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_arms, true_rewards,n_steps = 3, [0.2, 0.5, 0.75], 100
reward_sums, counts, estimated_rewards, reward_history, cumulative_rewards = np.zeros(n_arms), np.zeros(n_arms), np.zeros(n_arms), [], []

# %%
for arm in range(n_arms):
  reward = int(np.random.rand() < true_rewards[arm])
  reward_sums[arm] += reward
  counts[arm] += 1
  estimated_rewards[arm] = reward_sums[arm] / counts[arm]
  reward_history.append(reward)
  cumulative_rewards.append(sum(reward_history))


for step in range(n_arms, n_steps):
  arm = np.argmax(estimated_rewards)
  reward = int(np.random.rand() < true_rewards[arm])
  reward_sums[arm] += reward
  counts[arm] += 1
  estimated_rewards[arm] = reward_sums[arm] / counts[arm]
  reward_history.append(reward)
  cumulative_rewards.append(cumulative_rewards[-1] + reward)

# %%
print("\n=== Final Results ===")
print(f"True Reward Probabilities: {true_rewards}")
print(f"Estimated Reward Probabilities: {np.round(estimated_rewards, 2)}")
print(f"Number of times each arm was selected: {counts}")
print(f"Total Reward Earned: {int(sum(reward_history))}")


plt.figure(figsize=(10, 5))
plt.plot(cumulative_rewards, label="Cumulative Reward", color='blue')
plt.xlabel("Steps")
plt.ylabel("Total Reward")
plt.title("Greedy Agent - Reward Over Time")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# === Final Results ===
# True Reward Probabilities: [0.2, 0.5, 0.75]
# Estimated Reward Probabilities: [0.33 0.4  0.65]
# Number of times each arm was selected: [ 3.  5. 92.]
# Total Reward Earned: 63
